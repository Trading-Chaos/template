# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/GOLD_Williams_10years_H1.csv')
df
# Out:
#                DateTime    Open    High     Low   Close  Volume  \
# 0      2025.10.22 12:00  4067.4  4101.2  4067.0  4075.8    5408
# 1      2025.10.22 11:00  4133.3  4135.0  4059.5  4067.0   37270
# 2      2025.10.22 10:00  4161.5  4162.4  4131.5  4133.3   14160
# 3      2025.10.22 09:00  4134.9  4167.3  4127.2  4161.4   11817
# 4      2025.10.21 23:00  4112.0  4132.2  4109.3  4130.0    3724
# ...                 ...     ...     ...     ...     ...     ...
# 36375  2015.10.26 14:00  1169.3  1169.8  1168.5  1169.5      36
# 36376  2015.10.26 13:00  1168.0  1170.5  1167.6  1169.5      36
# 36377  2015.10.26 12:00  1167.7  1168.8  1166.3  1168.0      39
# 36378  2015.10.26 11:00  1164.5  1168.4  1164.2  1167.7      45
# 36379  2015.10.26 10:00  1167.4  1167.7  1164.1  1164.7      51
#
#        Alligator_Jaw  Alligator_Teeth  Alligator_Lips  Fractal_Up  \
# 0         4249.62339       4191.60913      4149.67401         NaN
# 1         4260.14617       4203.06044      4150.28001         NaN
# 2         4270.39585       4215.16907      4157.66252         NaN
# 3         4281.47050       4230.51465      4169.21564      4167.3
# 4         4288.22638       4245.82389      4181.94455         NaN
# ...              ...              ...             ...         ...
# 36375     1170.17277       1168.69690      1167.25851         NaN
# 36376     1170.55800       1168.94646      1167.49814      1170.5
# 36377     1171.01700       1169.11738      1167.89768         NaN
# 36378     1171.51841       1169.40558      1168.13460         NaN
# 36379     1172.08245       1169.95638      1168.23074         NaN
#
#        Fractal_Down         AO
# 0               NaN -118.37382
# 1               NaN -117.06706
# 2               NaN -116.57471
# 3               NaN -126.62206
# 4               NaN -133.63000
# ...             ...        ...
# 36375           NaN   -1.58500
# 36376           NaN   -2.02794
# 36377           NaN   -2.29824
# 36378           NaN   -2.42353
# 36379           NaN   -2.63382
#
# [36380 rows x 12 columns]

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36380 entries, 0 to 36379
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DateTime         36380 non-null  object
#  1   Open             36380 non-null  float64
#  2   High             36380 non-null  float64
#  3   Low              36380 non-null  float64
#  4   Close            36380 non-null  float64
#  5   Volume           36380 non-null  int64
#  6   Alligator_Jaw    36380 non-null  float64
#  7   Alligator_Teeth  36380 non-null  float64
#  8   Alligator_Lips   36380 non-null  float64
#  9   Fractal_Up       4831 non-null   float64
#  10  Fractal_Down     4861 non-null   float64
#  11  AO               36380 non-null  float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 3.3+ MB

# %% [markdown]
# Смотрим данные на наличие пропусков

# %%
for col in df.columns:
    pct_missing = df[col].isnull().mean()
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# DateTime - 0%
# Open - 0%
# High - 0%
# Low - 0%
# Close - 0%
# Volume - 0%
# Alligator_Jaw - 0%
# Alligator_Teeth - 0%
# Alligator_Lips - 0%
# Fractal_Up - 87%
# Fractal_Down - 87%
# AO - 0%

# %% [markdown]
# в фракталах добавим бинарность, тк много пропусков
#
# 1 вход для фрактала лонг
# -1 вход для фрактала шорт
#
# 0 отсутствие входа

# %%
df['Fractal_Down'] = df['Fractal_Down'].notna().astype(int)
df['Fractal_Up'] = df['Fractal_Up'].notna().astype(int)

for col in df.columns:
    pct_missing = df[col].isnull().mean()
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# DateTime - 0%
# Open - 0%
# High - 0%
# Low - 0%
# Close - 0%
# Volume - 0%
# Alligator_Jaw - 0%
# Alligator_Teeth - 0%
# Alligator_Lips - 0%
# Fractal_Up - 0%
# Fractal_Down - 0%
# AO - 0%

# %%
df. describe( include='all'). T
# Out:
#                    count unique               top freq         mean  \
# DateTime           36380  36380  2025.10.22 12:00    1          NaN
# Open             36380.0    NaN               NaN  NaN  1796.305874
# High             36380.0    NaN               NaN  NaN  1798.912763
# Low              36380.0    NaN               NaN  NaN  1793.632402
# Close            36380.0    NaN               NaN  NaN  1796.345701
# Volume           36380.0    NaN               NaN  NaN   418.100962
# Alligator_Jaw    36380.0    NaN               NaN  NaN  1794.608755
# Alligator_Teeth  36380.0    NaN               NaN  NaN  1795.285486
# Alligator_Lips   36380.0    NaN               NaN  NaN  1795.702183
# Fractal_Up       36380.0    NaN               NaN  NaN     0.132793
# Fractal_Down     36380.0    NaN               NaN  NaN     0.133617
# AO               36380.0    NaN               NaN  NaN     1.212287
#
#                          std         min          25%         50%  \
# DateTime                 NaN         NaN          NaN         NaN
# Open               602.04397      1049.8       1299.0     1750.05
# High              603.041882      1050.0       1300.3     1752.75
# Low               601.009296      1048.1       1297.6      1747.2
# Close              602.09372      1049.6       1299.1      1750.1
# Volume           1494.961479         1.0         52.0        59.0
# Alligator_Jaw     599.445069  1056.82964  1298.362515  1747.62345
# Alligator_Teeth   600.525904  1054.44959  1298.683397   1748.5081
# Alligator_Lips    601.172769  1052.33628   1298.77637  1749.43602
# Fractal_Up          0.339355         0.0          0.0         0.0
# Fractal_Down        0.340245         0.0          0.0         0.0
# AO                 13.809417     -133.63    -5.200513      0.6725
#
#                          75%         max
# DateTime                 NaN         NaN
# Open                  1957.3      4380.4
# High                  1959.9      4383.0
# Low                   1954.3      4362.6
# Close                 1957.2      4380.0
# Volume                  60.0     41418.0
# Alligator_Jaw    1957.647567  4302.07032
# Alligator_Teeth  1957.585015  4319.90682
# Alligator_Lips     1957.3012  4338.17626
# Fractal_Up               0.0         1.0
# Fractal_Down             0.0         1.0
# AO                  6.982425   116.28618

# %% [markdown]
# В классической стратегии нам нет смысла использовать объемы, поэтому убеерем их

# %%
df.drop(['Volume'], axis=1, inplace=True)
df
# Out:
#                DateTime    Open    High     Low   Close  Alligator_Jaw  \
# 0      2025.10.22 12:00  4067.4  4101.2  4067.0  4075.8     4249.62339
# 1      2025.10.22 11:00  4133.3  4135.0  4059.5  4067.0     4260.14617
# 2      2025.10.22 10:00  4161.5  4162.4  4131.5  4133.3     4270.39585
# 3      2025.10.22 09:00  4134.9  4167.3  4127.2  4161.4     4281.47050
# 4      2025.10.21 23:00  4112.0  4132.2  4109.3  4130.0     4288.22638
# ...                 ...     ...     ...     ...     ...            ...
# 36375  2015.10.26 14:00  1169.3  1169.8  1168.5  1169.5     1170.17277
# 36376  2015.10.26 13:00  1168.0  1170.5  1167.6  1169.5     1170.55800
# 36377  2015.10.26 12:00  1167.7  1168.8  1166.3  1168.0     1171.01700
# 36378  2015.10.26 11:00  1164.5  1168.4  1164.2  1167.7     1171.51841
# 36379  2015.10.26 10:00  1167.4  1167.7  1164.1  1164.7     1172.08245
#
#        Alligator_Teeth  Alligator_Lips  Fractal_Up  Fractal_Down         AO
# 0           4191.60913      4149.67401           0             0 -118.37382
# 1           4203.06044      4150.28001           0             0 -117.06706
# 2           4215.16907      4157.66252           0             0 -116.57471
# 3           4230.51465      4169.21564           1             0 -126.62206
# 4           4245.82389      4181.94455           0             0 -133.63000
# ...                ...             ...         ...           ...        ...
# 36375       1168.69690      1167.25851           0             0   -1.58500
# 36376       1168.94646      1167.49814           1             0   -2.02794
# 36377       1169.11738      1167.89768           0             0   -2.29824
# 36378       1169.40558      1168.13460           0             0   -2.42353
# 36379       1169.95638      1168.23074           0             0   -2.63382
#
# [36380 rows x 11 columns]

# %% [markdown]
# Cделаем новый столбец "Color AO" - тоже сделаем бинарный:
#
# - 1 зеленый - лонговый
#
# - -1 красный - шортовый

# %%
df['Color AO'] = df['AO'].diff().apply(lambda x: 1 if x > 0 else (-1 if x < 0 else 0))
df['Color AO'] = df['Color AO'].fillna(0).astype(int)

# %%
print(df[['AO', 'Color AO']].head(15))
print("\nРаспределение цветов баров:")
print(df['Color AO'].value_counts().sort_index())
# Out:
#            AO  Color AO
# 0  -118.37382         0
# 1  -117.06706         1
# 2  -116.57471         1
# 3  -126.62206        -1
# 4  -133.63000        -1
# 5  -133.31618         1
# 6  -131.42971         1
# 7  -118.32000         1
# 8   -96.31676         1
# 9   -72.05441         1
# 10  -49.73118         1
# 11  -27.23853         1
# 12  -12.91618         1
# 13    5.61118         1
# 14   21.22265         1
#
# Распределение цветов баров:
# Color AO
# -1    18153
#  0        6
#  1    18221
# Name: count, dtype: int64

# %% [markdown]
# добавляем перемменную и признаки для Аллигатора
#
# первый код = "что есть сигнал?"

# %%
# сортируем по дате на всякий случай
df = df.sort_values("DateTime").reset_index(drop=True)

# %% [markdown]
# Состояние Аллигатора

# %%
jaw, teeth, lips = df["Alligator_Jaw"], df["Alligator_Teeth"], df["Alligator_Lips"]

bullish = (lips > teeth) & (teeth > jaw) # бычий тренд
bearish = (jaw  > teeth) & (teeth > lips) # медвежий тренд

df["Alligator_Bullish"] = bullish.astype(int)
df["Alligator_Bearish"] = bearish.astype(int)

df["AlligatorStart_Long"]  = (bullish & ~bullish.shift(1, fill_value=False)).astype(int)
df["AlligatorStart_Short"] = (bearish & ~bearish.shift(1, fill_value=False)).astype(int)

# %% [markdown]
# Логика по АО

# %%
df["AO_sign"] = np.where(df["Color AO"] > 0, 1, -1)

df["AO_zero_up"]   = ((df["AO"] > 0) & (df["AO"].shift(1) <= 0)).astype(int)
df["AO_zero_down"] = ((df["AO"] < 0) & (df["AO"].shift(1) >= 0)).astype(int)

# три подряд бара одного цвета
df["AO_three_green"] = (
    (df["AO_sign"]==1) &
    (df["AO_sign"].shift(1)==1) &
    (df["AO_sign"].shift(2)==1)
).astype(int)

df["AO_three_red"] = (
    (df["AO_sign"]==-1) &
    (df["AO_sign"].shift(1)==-1) &
    (df["AO_sign"].shift(2)==-1)
).astype(int)

# блюдце по AO
df["AO_saucer_up"] = (
    (df["AO"] > 0) &
    (df["AO"].shift(2) > df["AO"].shift(1)) &
    (df["AO"] > df["AO"].shift(1))
).astype(int)

df["AO_saucer_down"] = (
    (df["AO"] < 0) &
    (df["AO"].shift(2) < df["AO"].shift(1)) &
    (df["AO"] < df["AO"].shift(1))
).astype(int)

# %% [markdown]
# Генерация сигналов входа

# %%
df["EntrySignal"] = 0
df["EntryReason"] = None

state = "flat"
last_alligator_side = 0

# %% [markdown]
# цикл по всем барам:

# %%
for i in range(len(df)):
    start_long  = bool(df.at[i, "AlligatorStart_Long"])
    start_short = bool(df.at[i, "AlligatorStart_Short"])

    # отслеживаем когда аллигатор открылся вверх/вниз
    if state in ("flat", "in_long", "in_short"):
        if start_long:
            state = "wait_long"; last_alligator_side = 1
        elif start_short:
            state = "wait_short"; last_alligator_side = -1

    # если появился новый «старт» аллигатора, переходим в режим ожидания сигнала AO (wait_long/wait_short)
    if state == "wait_long":
        if df.at[i, "AO_zero_up"]==1:
            df.at[i, "EntrySignal"] = 1; df.at[i, "EntryReason"] = "zero_cross"; state = "in_long"
        elif df.at[i, "AO_three_green"]==1:
            df.at[i, "EntrySignal"] = 1; df.at[i, "EntryReason"] = "three_color"; state = "in_long"
        elif df.at[i, "AO_saucer_up"]==1:
            df.at[i, "EntrySignal"] = 1; df.at[i, "EntryReason"] = "saucer"; state = "in_long"

    # В бычьем режиме ждём один из трёх паттернов AO
    # Как только он случился – ставим EntrySignal = 1, записываем причину и считаем, что мы «в лонге»
    elif state == "wait_short":
        if df.at[i, "AO_zero_down"]==1:
            df.at[i, "EntrySignal"] = -1; df.at[i, "EntryReason"] = "zero_cross"; state = "in_short"
        elif df.at[i, "AO_three_red"]==1:
            df.at[i, "EntrySignal"] = -1; df.at[i, "EntryReason"] = "three_color"; state = "in_short"
        elif df.at[i, "AO_saucer_down"]==1:
            df.at[i, "EntrySignal"] = -1; df.at[i, "EntryReason"] = "saucer"; state = "in_short"

    # То же для шорта
    if state in ("in_long", "wait_long") and start_short:
        state = "wait_short"; last_alligator_side = -1
        # Если во время ожидания/позиции появился противоположный аллигатор
        # – переключаемся на ожидание сигнала в новую сторону.
    if state in ("in_short", "wait_short") and start_long:
        state = "wait_long"; last_alligator_side = 1

# %% [markdown]
# Подтверждение фракталов
#
# Фрактал у Вильямса подтверждается спустя 2 бара. Поэтому здесь берётся значение фрактала 2 бара назад и переносится вперёд – чтобы на текущем баре понимать, что фрактал уже подтверждён.

# %%
df["Fractal_Up_conf"]   = df["Fractal_Up"].shift(2).fillna(0).astype(int)
df["Fractal_Down_conf"] = df["Fractal_Down"].shift(2).fillna(0).astype(int)

# %% [markdown]
# Логика добавления к позиции (AddOn)

# %%
df["AddOn_Anchor_Level"] = np.nan
df["AddOn_Anchor_IsUp"]  = np.nan
df["AddOn_Size_Pct"]     = np.nan
waiting_anchor = False
pos_side = 0

# Колонки для «якоря» добавочных входов:
# уровень цены, направление (1 – вверх, 0 – вниз), размер добавки (в процентах).
for i in range(len(df)):
    sig = int(df.at[i, "EntrySignal"])
    if sig != 0:
        pos_side = sig
        waiting_anchor = True
        continue
    # когда появился вход (EntrySignal ≠ 0) — запоминаем направление позиции и включаем режим waiting_anchor:
    #  ждём подходящего фрактала для постановки уровня добавки
    if waiting_anchor and pos_side == 1 and df.at[i, "Fractal_Up_conf"] == 1:
        df.at[i, "AddOn_Anchor_Level"] = df.at[i, "High"]
        df.at[i, "AddOn_Anchor_IsUp"]  = 1
        df.at[i, "AddOn_Size_Pct"]     = 0.30
        waiting_anchor = False
    # Если в лонге и появился подтверждённый верхний фрактал – его максимум становится AddOn_Anchor_Level,
    #  направление вверх, размер 30% от базовой позиции.
    if waiting_anchor and pos_side == -1 and df.at[i, "Fractal_Down_conf"] == 1:
        df.at[i, "AddOn_Anchor_Level"] = df.at[i, "Low"]
        df.at[i, "AddOn_Anchor_IsUp"]  = 0
        df.at[i, "AddOn_Size_Pct"]     = 0.30
        waiting_anchor = False

# %% [markdown]
# Аналогично для шорта (минимум фрактала).

# %%
df["AddOn_Anchor_Level"] = df["AddOn_Anchor_Level"].ffill()
df["AddOn_Anchor_IsUp"]  = df["AddOn_Anchor_IsUp"].ffill()
df["AddOn_Size_Pct"]     = df["AddOn_Size_Pct"].ffill()

# %%
df
# Out:
#                DateTime    Open    High     Low   Close  Alligator_Jaw  \
# 0      2015.10.26 10:00  1167.4  1167.7  1164.1  1164.7     1172.08245
# 1      2015.10.26 11:00  1164.5  1168.4  1164.2  1167.7     1171.51841
# 2      2015.10.26 12:00  1167.7  1168.8  1166.3  1168.0     1171.01700
# 3      2015.10.26 13:00  1168.0  1170.5  1167.6  1169.5     1170.55800
# 4      2015.10.26 14:00  1169.3  1169.8  1168.5  1169.5     1170.17277
# ...                 ...     ...     ...     ...     ...            ...
# 36375  2025.10.21 23:00  4112.0  4132.2  4109.3  4130.0     4288.22638
# 36376  2025.10.22 09:00  4134.9  4167.3  4127.2  4161.4     4281.47050
# 36377  2025.10.22 10:00  4161.5  4162.4  4131.5  4133.3     4270.39585
# 36378  2025.10.22 11:00  4133.3  4135.0  4059.5  4067.0     4260.14617
# 36379  2025.10.22 12:00  4067.4  4101.2  4067.0  4075.8     4249.62339
#
#        Alligator_Teeth  Alligator_Lips  Fractal_Up  Fractal_Down  ...  \
# 0           1169.95638      1168.23074           0             0  ...
# 1           1169.40558      1168.13460           0             0  ...
# 2           1169.11738      1167.89768           0             0  ...
# 3           1168.94646      1167.49814           1             0  ...
# 4           1168.69690      1167.25851           0             0  ...
# ...                ...             ...         ...           ...  ...
# 36375       4245.82389      4181.94455           0             0  ...
# 36376       4230.51465      4169.21564           1             0  ...
# 36377       4215.16907      4157.66252           0             0  ...
# 36378       4203.06044      4150.28001           0             0  ...
# 36379       4191.60913      4149.67401           0             0  ...
#
#        AO_three_red  AO_saucer_up  AO_saucer_down  EntrySignal  EntryReason  \
# 0                 0             0               0            0         None
# 1                 0             0               0            0         None
# 2                 1             0               0           -1  three_color
# 3                 1             0               0            0         None
# 4                 1             0               0            0         None
# ...             ...           ...             ...          ...          ...
# 36375             0             0               0            0         None
# 36376             0             0               0            0         None
# 36377             0             0               0            0         None
# 36378             0             0               1           -1       saucer
# 36379             0             0               0            0         None
#
#        Fractal_Up_conf  Fractal_Down_conf  AddOn_Anchor_Level  \
# 0                    0                  0                 NaN
# 1                    0                  0                 NaN
# 2                    0                  0                 NaN
# 3                    0                  0                 NaN
# 4                    0                  0                 NaN
# ...                ...                ...                 ...
# 36375                0                  0              4217.0
# 36376                0                  0              4217.0
# 36377                0                  0              4217.0
# 36378                1                  0              4217.0
# 36379                0                  0              4217.0
#
#        AddOn_Anchor_IsUp  AddOn_Size_Pct
# 0                    NaN             NaN
# 1                    NaN             NaN
# 2                    NaN             NaN
# 3                    NaN             NaN
# 4                    NaN             NaN
# ...                  ...             ...
# 36375                0.0             0.3
# 36376                0.0             0.3
# 36377                0.0             0.3
# 36378                0.0             0.3
# 36379                0.0             0.3
#
# [36380 rows x 30 columns]

# %% [markdown]
# второй код = «из чего модель будет его угадывать?».

# %%
df = df.copy().sort_values("DateTime").reset_index(drop=True)

# 1) Подтверждённые фракталы (каузально)
df["Fractal_Up_conf"]   = df["Fractal_Up"].shift(2).fillna(0).astype(int)
df["Fractal_Down_conf"] = df["Fractal_Down"].shift(2).fillna(0).astype(int)

# 2) Якорь добора — первый фрактал в сторону позиции ПОСЛЕ входа
df["AddOn_Anchor_Level"] = np.nan
df["AddOn_Anchor_IsUp"]  = np.nan  # 1=верхний, 0=нижний
df["AddOn_Size_Pct"]     = np.nan
df["AddOn_Ready"]        = 0       # «якорь найден, добор ещё не выполнен»
df["AddOn_Triggered"]    = 0       # «добор исполнен по цене якоря»

in_pos = 0           # +1 long, -1 short, 0 flat
anchor_set = False   # найден ли якорь добора для текущей сделки
addon_done = False   # добор уже выполнен?

for i in range(len(df)):
    sig = int(df.at[i, "EntrySignal"]) if "EntrySignal" in df.columns else 0

    # вход открывает новую «сделку»
    if in_pos == 0 and sig != 0:
        in_pos = sig
        anchor_set = False
        addon_done = False
        continue  # на самом баре входа якорь ещё не может появиться (фракталы подтверждаются позже)

    # если в позиции и якорь ещё не выбран — ловим ПЕРВЫЙ подтверждённый фрактал в сторону сделки
    if in_pos == 1 and not anchor_set and df.at[i, "Fractal_Up_conf"] == 1:
        df.at[i, "AddOn_Anchor_Level"] = df.at[i, "High"]
        df.at[i, "AddOn_Anchor_IsUp"]  = 1
        df.at[i, "AddOn_Size_Pct"]     = 0.30
        df.at[i, "AddOn_Ready"]        = 1
        anchor_set = True
    elif in_pos == -1 and not anchor_set and df.at[i, "Fractal_Down_conf"] == 1:
        df.at[i, "AddOn_Anchor_Level"] = df.at[i, "Low"]
        df.at[i, "AddOn_Anchor_IsUp"]  = 0
        df.at[i, "AddOn_Size_Pct"]     = 0.30
        df.at[i, "AddOn_Ready"]        = 1
        anchor_set = True

    # если якорь выбран, проверим срабатывание (по High/Low)
    if anchor_set and not addon_done:
        anchor = df.at[i, "AddOn_Anchor_Level"]
        if in_pos == 1 and not pd.isna(anchor) and df.at[i, "High"] >= anchor:
            df.at[i, "AddOn_Triggered"] = 1
            addon_done = True
        elif in_pos == -1 and not pd.isna(anchor) and df.at[i, "Low"] <= anchor:
            df.at[i, "AddOn_Triggered"] = 1
            addon_done = True

    # выход по развороту аллигатора обнуляет состояние (если у тебя уже есть ExitSignal — можно использовать его)
    # Здесь считаем flip как смену устойчивого порядка:
    jaw, teeth, lips = df["Alligator_Jaw"], df["Alligator_Teeth"], df["Alligator_Lips"]
    bullish = (lips > teeth) & (teeth > jaw)
    bearish = (jaw  > teeth) & (teeth > lips)
    start_long  = bool(bullish.iloc[i] and not bullish.shift(1, fill_value=False).iloc[i])
    start_short = bool(bearish.iloc[i] and not bearish.shift(1, fill_value=False).iloc[i])

    if in_pos == 1 and start_short:
        in_pos = 0; anchor_set = False; addon_done = False
    elif in_pos == -1 and start_long:
        in_pos = 0; anchor_set = False; addon_done = False

# протащим постоянные значения якоря вперёд до конца сделки (удобно для исполнителя)
df["AddOn_Anchor_Level"] = df["AddOn_Anchor_Level"].ffill()
df["AddOn_Anchor_IsUp"]  = df["AddOn_Anchor_IsUp"].ffill()
df["AddOn_Size_Pct"]     = df["AddOn_Size_Pct"].ffill()

# %%
df
# Out:
#                DateTime    Open    High     Low   Close  Alligator_Jaw  \
# 0      2015.10.26 10:00  1167.4  1167.7  1164.1  1164.7     1172.08245
# 1      2015.10.26 11:00  1164.5  1168.4  1164.2  1167.7     1171.51841
# 2      2015.10.26 12:00  1167.7  1168.8  1166.3  1168.0     1171.01700
# 3      2015.10.26 13:00  1168.0  1170.5  1167.6  1169.5     1170.55800
# 4      2015.10.26 14:00  1169.3  1169.8  1168.5  1169.5     1170.17277
# ...                 ...     ...     ...     ...     ...            ...
# 36375  2025.10.21 23:00  4112.0  4132.2  4109.3  4130.0     4288.22638
# 36376  2025.10.22 09:00  4134.9  4167.3  4127.2  4161.4     4281.47050
# 36377  2025.10.22 10:00  4161.5  4162.4  4131.5  4133.3     4270.39585
# 36378  2025.10.22 11:00  4133.3  4135.0  4059.5  4067.0     4260.14617
# 36379  2025.10.22 12:00  4067.4  4101.2  4067.0  4075.8     4249.62339
#
#        Alligator_Teeth  Alligator_Lips  Fractal_Up  Fractal_Down  ...  \
# 0           1169.95638      1168.23074           0             0  ...
# 1           1169.40558      1168.13460           0             0  ...
# 2           1169.11738      1167.89768           0             0  ...
# 3           1168.94646      1167.49814           1             0  ...
# 4           1168.69690      1167.25851           0             0  ...
# ...                ...             ...         ...           ...  ...
# 36375       4245.82389      4181.94455           0             0  ...
# 36376       4230.51465      4169.21564           1             0  ...
# 36377       4215.16907      4157.66252           0             0  ...
# 36378       4203.06044      4150.28001           0             0  ...
# 36379       4191.60913      4149.67401           0             0  ...
#
#        AO_saucer_down  EntrySignal  EntryReason  Fractal_Up_conf  \
# 0                   0            0         None                0
# 1                   0            0         None                0
# 2                   0           -1  three_color                0
# 3                   0            0         None                0
# 4                   0            0         None                0
# ...               ...          ...          ...              ...
# 36375               0            0         None                0
# 36376               0            0         None                0
# 36377               0            0         None                0
# 36378               1           -1       saucer                1
# 36379               0            0         None                0
#
#        Fractal_Down_conf  AddOn_Anchor_Level  AddOn_Anchor_IsUp  \
# 0                      0                 NaN                NaN
# 1                      0                 NaN                NaN
# 2                      0                 NaN                NaN
# 3                      0                 NaN                NaN
# 4                      0                 NaN                NaN
# ...                  ...                 ...                ...
# 36375                  0              4217.0                0.0
# 36376                  0              4217.0                0.0
# 36377                  0              4217.0                0.0
# 36378                  0              4217.0                0.0
# 36379                  0              4217.0                0.0
#
#        AddOn_Size_Pct  AddOn_Ready  AddOn_Triggered
# 0                 NaN            0                0
# 1                 NaN            0                0
# 2                 NaN            0                0
# 3                 NaN            0                0
# 4                 NaN            0                0
# ...               ...          ...              ...
# 36375             0.3            0                0
# 36376             0.3            0                0
# 36377             0.3            0                0
# 36378             0.3            0                0
# 36379             0.3            0                0
#
# [36380 rows x 32 columns]

# %% [markdown]
# Предобработка временных меток в DataFrame

# %%
df = df.copy().sort_values("DateTime").reset_index(drop=True)
df["DateTime"] = pd.to_datetime(df["DateTime"], errors="coerce")
df = df[df["DateTime"].notna()].reset_index(drop=True)

# %%
df
# Out:
#                  DateTime    Open    High     Low   Close  Alligator_Jaw  \
# 0     2015-10-26 10:00:00  1167.4  1167.7  1164.1  1164.7     1172.08245
# 1     2015-10-26 11:00:00  1164.5  1168.4  1164.2  1167.7     1171.51841
# 2     2015-10-26 12:00:00  1167.7  1168.8  1166.3  1168.0     1171.01700
# 3     2015-10-26 13:00:00  1168.0  1170.5  1167.6  1169.5     1170.55800
# 4     2015-10-26 14:00:00  1169.3  1169.8  1168.5  1169.5     1170.17277
# ...                   ...     ...     ...     ...     ...            ...
# 36375 2025-10-21 23:00:00  4112.0  4132.2  4109.3  4130.0     4288.22638
# 36376 2025-10-22 09:00:00  4134.9  4167.3  4127.2  4161.4     4281.47050
# 36377 2025-10-22 10:00:00  4161.5  4162.4  4131.5  4133.3     4270.39585
# 36378 2025-10-22 11:00:00  4133.3  4135.0  4059.5  4067.0     4260.14617
# 36379 2025-10-22 12:00:00  4067.4  4101.2  4067.0  4075.8     4249.62339
#
#        Alligator_Teeth  Alligator_Lips  Fractal_Up  Fractal_Down  ...  \
# 0           1169.95638      1168.23074           0             0  ...
# 1           1169.40558      1168.13460           0             0  ...
# 2           1169.11738      1167.89768           0             0  ...
# 3           1168.94646      1167.49814           1             0  ...
# 4           1168.69690      1167.25851           0             0  ...
# ...                ...             ...         ...           ...  ...
# 36375       4245.82389      4181.94455           0             0  ...
# 36376       4230.51465      4169.21564           1             0  ...
# 36377       4215.16907      4157.66252           0             0  ...
# 36378       4203.06044      4150.28001           0             0  ...
# 36379       4191.60913      4149.67401           0             0  ...
#
#        AO_saucer_down  EntrySignal  EntryReason  Fractal_Up_conf  \
# 0                   0            0         None                0
# 1                   0            0         None                0
# 2                   0           -1  three_color                0
# 3                   0            0         None                0
# 4                   0            0         None                0
# ...               ...          ...          ...              ...
# 36375               0            0         None                0
# 36376               0            0         None                0
# 36377               0            0         None                0
# 36378               1           -1       saucer                1
# 36379               0            0         None                0
#
#        Fractal_Down_conf  AddOn_Anchor_Level  AddOn_Anchor_IsUp  \
# 0                      0                 NaN                NaN
# 1                      0                 NaN                NaN
# 2                      0                 NaN                NaN
# 3                      0                 NaN                NaN
# 4                      0                 NaN                NaN
# ...                  ...                 ...                ...
# 36375                  0              4217.0                0.0
# 36376                  0              4217.0                0.0
# 36377                  0              4217.0                0.0
# 36378                  0              4217.0                0.0
# 36379                  0              4217.0                0.0
#
#        AddOn_Size_Pct  AddOn_Ready  AddOn_Triggered
# 0                 NaN            0                0
# 1                 NaN            0                0
# 2                 NaN            0                0
# 3                 NaN            0                0
# 4                 NaN            0                0
# ...               ...          ...              ...
# 36375             0.3            0                0
# 36376             0.3            0                0
# 36377             0.3            0                0
# 36378             0.3            0                0
# 36379             0.3            0                0
#
# [36380 rows x 32 columns]

# %%
for col in df.columns:
    pct_missing = df[col].isnull().mean()
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# DateTime - 0%
# Open - 0%
# High - 0%
# Low - 0%
# Close - 0%
# Alligator_Jaw - 0%
# Alligator_Teeth - 0%
# Alligator_Lips - 0%
# Fractal_Up - 0%
# Fractal_Down - 0%
# AO - 0%
# Color AO - 0%
# Alligator_Bullish - 0%
# Alligator_Bearish - 0%
# AlligatorStart_Long - 0%
# AlligatorStart_Short - 0%
# AO_sign - 0%
# AO_zero_up - 0%
# AO_zero_down - 0%
# AO_three_green - 0%
# AO_three_red - 0%
# AO_saucer_up - 0%
# AO_saucer_down - 0%
# EntrySignal - 0%
# EntryReason - 95%
# Fractal_Up_conf - 0%
# Fractal_Down_conf - 0%
# AddOn_Anchor_Level - 0%
# AddOn_Anchor_IsUp - 0%
# AddOn_Size_Pct - 0%
# AddOn_Ready - 0%
# AddOn_Triggered - 0%

# %%
df.describe(include='all').T
# Out:
#                         count unique          top  freq  \
# DateTime                36380    NaN          NaN   NaN
# Open                  36380.0    NaN          NaN   NaN
# High                  36380.0    NaN          NaN   NaN
# Low                   36380.0    NaN          NaN   NaN
# Close                 36380.0    NaN          NaN   NaN
# Alligator_Jaw         36380.0    NaN          NaN   NaN
# Alligator_Teeth       36380.0    NaN          NaN   NaN
# Alligator_Lips        36380.0    NaN          NaN   NaN
# Fractal_Up            36380.0    NaN          NaN   NaN
# Fractal_Down          36380.0    NaN          NaN   NaN
# AO                    36380.0    NaN          NaN   NaN
# Color AO              36380.0    NaN          NaN   NaN
# Alligator_Bullish     36380.0    NaN          NaN   NaN
# Alligator_Bearish     36380.0    NaN          NaN   NaN
# AlligatorStart_Long   36380.0    NaN          NaN   NaN
# AlligatorStart_Short  36380.0    NaN          NaN   NaN
# AO_sign               36380.0    NaN          NaN   NaN
# AO_zero_up            36380.0    NaN          NaN   NaN
# AO_zero_down          36380.0    NaN          NaN   NaN
# AO_three_green        36380.0    NaN          NaN   NaN
# AO_three_red          36380.0    NaN          NaN   NaN
# AO_saucer_up          36380.0    NaN          NaN   NaN
# AO_saucer_down        36380.0    NaN          NaN   NaN
# EntrySignal           36380.0    NaN          NaN   NaN
# EntryReason              1833      3  three_color  1331
# Fractal_Up_conf       36380.0    NaN          NaN   NaN
# Fractal_Down_conf     36380.0    NaN          NaN   NaN
# AddOn_Anchor_Level    36372.0    NaN          NaN   NaN
# AddOn_Anchor_IsUp     36372.0    NaN          NaN   NaN
# AddOn_Size_Pct        36372.0    NaN          NaN   NaN
# AddOn_Ready           36380.0    NaN          NaN   NaN
# AddOn_Triggered       36380.0    NaN          NaN   NaN
#
#                                                mean                  min  \
# DateTime              2020-11-22 20:26:15.865860352  2015-10-26 10:00:00
# Open                                    1796.305874               1049.8
# High                                    1798.912763               1050.0
# Low                                     1793.632402               1048.1
# Close                                   1796.345701               1049.6
# Alligator_Jaw                           1794.608755           1056.82964
# Alligator_Teeth                         1795.285486           1054.44959
# Alligator_Lips                          1795.702183           1052.33628
# Fractal_Up                                 0.132793                  0.0
# Fractal_Down                               0.133617                  0.0
# AO                                         1.212287              -133.63
# Color AO                                   0.001869                 -1.0
# Alligator_Bullish                           0.43851                  0.0
# Alligator_Bearish                          0.373117                  0.0
# AlligatorStart_Long                        0.025646                  0.0
# AlligatorStart_Short                       0.026306                  0.0
# AO_sign                                    0.001704                 -1.0
# AO_zero_up                                 0.020753                  0.0
# AO_zero_down                               0.020753                  0.0
# AO_three_green                             0.344887                  0.0
# AO_three_red                               0.343238                  0.0
# AO_saucer_up                               0.037905                  0.0
# AO_saucer_down                             0.031089                  0.0
# EntrySignal                               -0.000357                 -1.0
# EntryReason                                     NaN                  NaN
# Fractal_Up_conf                            0.132793                  0.0
# Fractal_Down_conf                          0.133617                  0.0
# AddOn_Anchor_Level                      1791.779259               1049.6
# AddOn_Anchor_IsUp                          0.523645                  0.0
# AddOn_Size_Pct                                  0.3                  0.3
# AddOn_Ready                                0.023172                  0.0
# AddOn_Triggered                            0.023172                  0.0
#
#                                       25%                  50%  \
# DateTime              2018-05-28 21:45:00  2020-12-23 14:30:00
# Open                               1299.0              1750.05
# High                               1300.3              1752.75
# Low                                1297.6               1747.2
# Close                              1299.1               1750.1
# Alligator_Jaw                 1298.362515           1747.62345
# Alligator_Teeth               1298.683397            1748.5081
# Alligator_Lips                 1298.77637           1749.43602
# Fractal_Up                            0.0                  0.0
# Fractal_Down                          0.0                  0.0
# AO                              -5.200513               0.6725
# Color AO                             -1.0                  1.0
# Alligator_Bullish                     0.0                  0.0
# Alligator_Bearish                     0.0                  0.0
# AlligatorStart_Long                   0.0                  0.0
# AlligatorStart_Short                  0.0                  0.0
# AO_sign                              -1.0                  1.0
# AO_zero_up                            0.0                  0.0
# AO_zero_down                          0.0                  0.0
# AO_three_green                        0.0                  0.0
# AO_three_red                          0.0                  0.0
# AO_saucer_up                          0.0                  0.0
# AO_saucer_down                        0.0                  0.0
# EntrySignal                           0.0                  0.0
# EntryReason                           NaN                  NaN
# Fractal_Up_conf                       0.0                  0.0
# Fractal_Down_conf                     0.0                  0.0
# AddOn_Anchor_Level                 1297.7               1754.8
# AddOn_Anchor_IsUp                     0.0                  1.0
# AddOn_Size_Pct                        0.3                  0.3
# AddOn_Ready                           0.0                  0.0
# AddOn_Triggered                       0.0                  0.0
#
#                                       75%                  max         std
# DateTime              2023-05-31 22:15:00  2025-10-22 12:00:00         NaN
# Open                               1957.3               4380.4   602.04397
# High                               1959.9               4383.0  603.041882
# Low                                1954.3               4362.6  601.009296
# Close                              1957.2               4380.0   602.09372
# Alligator_Jaw                 1957.647567           4302.07032  599.445069
# Alligator_Teeth               1957.585015           4319.90682  600.525904
# Alligator_Lips                  1957.3012           4338.17626  601.172769
# Fractal_Up                            0.0                  1.0    0.339355
# Fractal_Down                          0.0                  1.0    0.340245
# AO                               6.982425            116.28618   13.809417
# Color AO                              1.0                  1.0     0.99993
# Alligator_Bullish                     1.0                  1.0    0.496211
# Alligator_Bearish                     1.0                  1.0    0.483639
# AlligatorStart_Long                   0.0                  1.0    0.158079
# AlligatorStart_Short                  0.0                  1.0    0.160045
# AO_sign                               1.0                  1.0    1.000012
# AO_zero_up                            0.0                  1.0    0.142559
# AO_zero_down                          0.0                  1.0    0.142559
# AO_three_green                        1.0                  1.0    0.475338
# AO_three_red                          1.0                  1.0    0.474797
# AO_saucer_up                          0.0                  1.0     0.19097
# AO_saucer_down                        0.0                  1.0    0.173559
# EntrySignal                           0.0                  1.0    0.224468
# EntryReason                           NaN                  NaN         NaN
# Fractal_Up_conf                       0.0                  1.0    0.339355
# Fractal_Down_conf                     0.0                  1.0    0.340245
# AddOn_Anchor_Level                 1957.8               4217.0  593.641365
# AddOn_Anchor_IsUp                     1.0                  1.0    0.499447
# AddOn_Size_Pct                        0.3                  0.3         0.0
# AddOn_Ready                           0.0                  1.0    0.150452
# AddOn_Triggered                       0.0                  1.0    0.150452

# %%
df.to_csv("../clean_df/Gold.csv", index=False)
